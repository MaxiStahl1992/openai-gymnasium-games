# %% [markdown]
# # 1. Import dependencies

# %%
import gymnasium as gym
import os
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# # 2. Load environment

# %%
environment_name = 'CartPole-v1'
env = gym.make(environment_name)
env.reset()
# Out:
# (array([-0.02960015, -0.00293233, -0.03210034, -0.01111461], dtype=float32),
#  {})

# %%
episodes = 10
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0

    while not done:
        action = env.action_space.sample()
        n_state, reward, done, truncated,  info = env.step(action)
        score += reward
    print('Episode: {} Score: {}'.format(episode, score))
# Out:
# Episode: 1 Score: 12.0
# Episode: 2 Score: 24.0
# Episode: 3 Score: 14.0
# Episode: 4 Score: 20.0
# Episode: 5 Score: 13.0
# Episode: 6 Score: 14.0
# Episode: 7 Score: 23.0
# Episode: 8 Score: 13.0
# Episode: 9 Score: 18.0
# Episode: 10 Score: 10.0

# %% [markdown]
# ## Understanding the environment

# %%
# 0-push cart to left, 1-push cart to the right
env.action_space.sample()
# Out:
# np.int64(0)

# %%
# [cart position, cart velocity, pole angle, pole angular velocity]
env.observation_space.sample()
# Out:
# array([ 2.4286697e+00,  2.6898864e+38,  2.4621819e-01, -2.9737029e+37],
#       dtype=float32)

# %% [markdown]
# # 3. Training a RL Model

# %%
log_path = os.path.join('Training', 'Logs') # directories need to exist before training
log_path
# Out:
# 'Training/Logs'

# %%
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000)
# Out:
# Logging to Training/Logs/PPO_1
# -----------------------------
# | time/              |      |
# |    fps             | 6952 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4705         |
# |    iterations           | 2            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.010147203  |
# |    clip_fraction        | 0.127        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.685       |
# |    explained_variance   | -0.016705036 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.65         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0187      |
# |    value_loss           | 47.6         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4208        |
# |    iterations           | 3           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009935448 |
# |    clip_fraction        | 0.0736      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.666      |
# |    explained_variance   | 0.10784328  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.6        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0168     |
# |    value_loss           | 34.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4095        |
# |    iterations           | 4           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010026602 |
# |    clip_fraction        | 0.0948      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.635      |
# |    explained_variance   | 0.23279017  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.2        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0212     |
# |    value_loss           | 53.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4029        |
# |    iterations           | 5           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008000816 |
# |    clip_fraction        | 0.0764      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.603      |
# |    explained_variance   | 0.30810744  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.1        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0177     |
# |    value_loss           | 56.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3994        |
# |    iterations           | 6           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011528011 |
# |    clip_fraction        | 0.0826      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.591      |
# |    explained_variance   | 0.39219344  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.7        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0145     |
# |    value_loss           | 66.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3966        |
# |    iterations           | 7           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.011029506 |
# |    clip_fraction        | 0.073       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.577      |
# |    explained_variance   | 0.57189596  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.5        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00932    |
# |    value_loss           | 52.2        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3951         |
# |    iterations           | 8            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0063308105 |
# |    clip_fraction        | 0.065        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.59        |
# |    explained_variance   | 0.71542346   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.44         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00838     |
# |    value_loss           | 38.4         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3940         |
# |    iterations           | 9            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0069222543 |
# |    clip_fraction        | 0.0406       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.569       |
# |    explained_variance   | 0.61564136   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23.1         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.0038      |
# |    value_loss           | 62.2         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3927         |
# |    iterations           | 10           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0043822285 |
# |    clip_fraction        | 0.0423       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.579       |
# |    explained_variance   | 0.5599282    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28.1         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00906     |
# |    value_loss           | 51.2         |
# ------------------------------------------

# %% [markdown]
# # 4. Save and Reload Model

# %%
PPO_path = os.path.join('Training', 'Saved Models', 'PPO_Model_CartPole')
model.save(PPO_path)

# %%
del model

# %%
model.learn(total_timesteps=20000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 model.learn(total_timesteps=20000)
#
# NameError: name 'model' is not defined

# %%
model = PPO.load(PPO_path, env=env) # load the model from the saved path

# %% [markdown]
# # 5. Evaluation

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=False)
# Out:
# (np.float64(500.0), np.float64(0.0))

# %%
env.close() # close the environment

# %% [markdown]
# # 6. Test

# %%
episodes = 10
for episode in range(1, episodes+1):
    obs = env.reset()
    done = False
    score = 0

    while not done:
        action, _ = model.predict(obs)
        obs, reward, done, info = env.step(action)
        score += reward
    print('Episode: {} Score: {}'.format(episode, score))
# Out:
# Episode: 1 Score: [500.]
# Episode: 2 Score: [500.]
# Episode: 3 Score: [268.]
# Episode: 4 Score: [481.]
# Episode: 5 Score: [500.]
# Episode: 6 Score: [500.]
# Episode: 7 Score: [469.]
# Episode: 8 Score: [500.]
# Episode: 9 Score: [419.]
# Episode: 10 Score: [500.]

# %%
obs = env.reset()

# %%
action, _ = model.predict(obs)

# %%
env.action_space.sample()
# Out:
# np.int64(1)

# %%
env.step(action)
# Out:
# (array([[ 0.03981717, -0.20893186,  0.04524281,  0.3453281 ]],
#        dtype=float32),
#  array([1.], dtype=float32),
#  array([False]),
#  [{'TimeLimit.truncated': False}])

# %% [markdown]
# # 7. View Logs in Tensorboard
#
# -> Usually executed from a terminal not inside a notebook

# %%
training_log_path = os.path.join(log_path, 'PPO_2')

# %%
# !tensorboard --logdir={training_log_path}
# Out:
# TensorFlow installation not found - running with reduced feature set.
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.17.1 at http://localhost:6006/ (Press CTRL+C to quit)
# ^C

# %% [markdown]
# # 8. Add a Callback Stage

# %%
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold

# %%
save_path = os.path.join('Training', 'Saved_Models', 'PPO_Model_CartPole')

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=300, verbose=1)
eval_callback = EvalCallback(env, callback_on_new_best=stop_callback, eval_freq=10000, best_model_save_path=save_path, verbose=1)

# %%
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to Training/Logs/PPO_7
# -----------------------------
# | time/              |      |
# |    fps             | 7064 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4970         |
# |    iterations           | 2            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.009247511  |
# |    clip_fraction        | 0.122        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.685       |
# |    explained_variance   | -0.007834554 |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.23         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0189      |
# |    value_loss           | 51.9         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4523        |
# |    iterations           | 3           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009005351 |
# |    clip_fraction        | 0.0564      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.663      |
# |    explained_variance   | 0.08304471  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.3        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0148     |
# |    value_loss           | 33.9        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4309         |
# |    iterations           | 4            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0074106697 |
# |    clip_fraction        | 0.0669       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.632       |
# |    explained_variance   | 0.15171331   |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.5         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0162      |
# |    value_loss           | 53.1         |
# ------------------------------------------
# Eval num_timesteps=10000, episode_reward=376.00 +/- 110.12
# Episode length: 376.00 +/- 110.12
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 376         |
# |    mean_reward          | 376         |
# | time/                   |             |
# |    total_timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.011189701 |
# |    clip_fraction        | 0.0963      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.602      |
# |    explained_variance   | 0.36043817  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.3        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0199     |
# |    value_loss           | 57          |
# -----------------------------------------
# New best mean reward!
# Stopping training because the mean reward 376.00  is above the threshold 300
# /Users/stahlma/anaconda3/envs/gymnasium_env/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(

# %% [markdown]
# # 9. Changing Policies

# %%
new_arch = dict(pi=[128, 128, 128, 128], vf=[128, 128, 128, 128])
model = PPO('MlpPolicy', env, verbose=1, policy_kwargs={'net_arch': new_arch}, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to Training/Logs/PPO_8
# -----------------------------
# | time/              |      |
# |    fps             | 5321 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3480          |
# |    iterations           | 2             |
# |    time_elapsed         | 1             |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.013313074   |
# |    clip_fraction        | 0.163         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.683        |
# |    explained_variance   | 0.00024664402 |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.61          |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.0204       |
# |    value_loss           | 18.4          |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3142        |
# |    iterations           | 3           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.016810734 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.64       |
# |    explained_variance   | 0.44742286  |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.4        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0362     |
# |    value_loss           | 26          |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2995         |
# |    iterations           | 4            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0151436925 |
# |    clip_fraction        | 0.189        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.601       |
# |    explained_variance   | 0.477143     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.8         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0314      |
# |    value_loss           | 41.9         |
# ------------------------------------------
# /Users/stahlma/anaconda3/envs/gymnasium_env/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=10000, episode_reward=385.80 +/- 99.09
# Episode length: 385.80 +/- 99.09
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 386         |
# |    mean_reward          | 386         |
# | time/                   |             |
# |    total_timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.010932865 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.578      |
# |    explained_variance   | 0.4775414   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.3        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0171     |
# |    value_loss           | 38          |
# -----------------------------------------
# New best mean reward!
# Stopping training because the mean reward 385.80  is above the threshold 300

# %% [markdown]
# # 10. Use an alternate Algorithm

# %%
from stable_baselines3 import DQN

# %%
model = DQN('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to Training/Logs/DQN_1
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.969    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 12716    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 66       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.925    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 7214     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 157      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.608    |
# |    n_updates        | 14       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.891    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 6132     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 229      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.55     |
# |    n_updates        | 32       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.858    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 5390     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 298      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.523    |
# |    n_updates        | 49       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.829    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 5154     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 360      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.502    |
# |    n_updates        | 64       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.788    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 3983     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 447      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.487    |
# |    n_updates        | 86       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.756    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 3958     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 514      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.415    |
# |    n_updates        | 103      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.709    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 4138     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 613      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.387    |
# |    n_updates        | 128      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.679    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 4218     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 676      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.314    |
# |    n_updates        | 143      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.651    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 4253     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 734      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.264    |
# |    n_updates        | 158      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.623    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 4286     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 794      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.252    |
# |    n_updates        | 173      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.6      |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 4317     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 843      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.217    |
# |    n_updates        | 185      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.575    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 4324     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 894      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.209    |
# |    n_updates        | 198      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.547    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 4375     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 953      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.176    |
# |    n_updates        | 213      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.526    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 4377     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 998      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.173    |
# |    n_updates        | 224      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.503    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 4371     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1046     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.134    |
# |    n_updates        | 236      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.472    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 4424     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1112     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.14     |
# |    n_updates        | 252      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.452    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 4424     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1153     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0914   |
# |    n_updates        | 263      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.428    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 4440     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1205     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0833   |
# |    n_updates        | 276      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.405    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 4443     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1253     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0787   |
# |    n_updates        | 288      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.384    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 4462     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1296     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0862   |
# |    n_updates        | 298      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.357    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 4476     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1354     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0571   |
# |    n_updates        | 313      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.336    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 4461     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1398     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0563   |
# |    n_updates        | 324      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.313    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 4481     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1447     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0478   |
# |    n_updates        | 336      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.293    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 
|
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00111  |
# |    n_updates        | 1052     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 4309     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4360     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000388 |
# |    n_updates        | 1064     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 4307     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4404     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000414 |
# |    n_updates        | 1075     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 4307     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4451     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00243  |
# |    n_updates        | 1087     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 4307     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4496     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000253 |
# |    n_updates        | 1098     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 4303     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4537     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00121  |
# |    n_updates        | 1109     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 4301     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4577     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000344 |
# |    n_updates        | 1119     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 4305     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4620     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000263 |
# |    n_updates        | 1129     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 4305     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4664     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000276 |
# |    n_updates        | 1140     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 4305     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4709     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000223 |
# |    n_updates        | 1152     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 4305     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4756     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00128  |
# |    n_updates        | 1163     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 4303     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4804     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000193 |
# |    n_updates        | 1175     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 4302     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4850     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000528 |
# |    n_updates        | 1187     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 4302     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4898     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00289  |
# |    n_updates        | 1199     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 4302     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4944     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000455 |
# |    n_updates        | 1210     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 4303     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4990     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000315 |
# |    n_updates        | 1222     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 4306     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5032     |
# | train/              |          |
# ...
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1528     |
# |    fps              | 4194     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 18732    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0278   |
# |    n_updates        | 4657     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1532     |
# |    fps              | 4188     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 18769    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0524   |
# |    n_updates        | 4667     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1536     |
# |    fps              | 4186     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 18806    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0253   |
# |    n_updates        | 4676     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1540     |
# |    fps              | 4183     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 18842    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0222   |
# |    n_updates        | 4685     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1544     |
# |    fps              | 4179     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 18880    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0304   |
# |    n_updates        | 4694     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1548     |
# |    fps              | 4178     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 18918    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0377   |
# |    n_updates        | 4704     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1552     |
# |    fps              | 4177     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 18955    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.046    |
# |    n_updates        | 4713     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1556     |
# |    fps              | 4175     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 18993    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0299   |
# |    n_updates        | 4723     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1560     |
# |    fps              | 4175     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19032    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0137   |
# |    n_updates        | 4732     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1564     |
# |    fps              | 4174     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19071    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0212   |
# |    n_updates        | 4742     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1568     |
# |    fps              | 4174     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19105    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0279   |
# |    n_updates        | 4751     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1572     |
# |    fps              | 4174     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19143    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0286   |
# |    n_updates        | 4760     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1576     |
# |    fps              | 4174     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19182    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.047    |
# |    n_updates        | 4770     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1580     |
# |    fps              | 4173     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19219    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0156   |
# |    n_updates        | 4779     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1584     |
# |    fps              | 4173     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19256    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0303   |
# |    n_updates        | 4788     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1588     |
# |    fps              | 4173     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19295    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0455   |
# |    n_updates        | 4798     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1592     |
# |    fps              | 4172     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19332    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0321   |
# |    n_updates        | 4807     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1596     |
# |    fps              | 4172     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19370    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.043    |
# |    n_updates        | 4817     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1600     |
# |    fps              | 4172     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19409    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0318   |
# |    n_updates        | 4827     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1604     |
# |    fps              | 4172     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19446    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0169   |
# |    n_updates        | 4836     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1608     |
# |    fps              | 4172     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19485    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0446   |
# |    n_updates        | 4846     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1612     |
# |    fps              | 4173     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19526    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0333   |
# |    n_updates        | 4856     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1616     |
# |    fps              | 4173     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19561    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0283   |
# |    n_updates        | 4865     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1620     |
# |    fps              | 4173     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19600    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0333   |
# |    n_updates        | 4874     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1624     |
# |    fps              | 4173     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19637    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0578   |
# |    n_updates        | 4884     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1628     |
# |    fps              | 4173     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19672    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00764  |
# |    n_updates        | 4892     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1632     |
# |    fps              | 4173     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19708    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.035    |
# |    n_updates        | 4901     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1636     |
# |    fps              | 4173     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19749    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0171   |
# |    n_updates        | 4912     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1640     |
# |    fps              | 4173     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19787    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00434  |
# |    n_updates        | 4921     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1644     |
# |    fps              | 4173     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19830    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0224   |
# |    n_updates        | 4932     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1648     |
# |    fps              | 4173     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19867    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0354   |
# |    n_updates        | 4941     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1652     |
# |    fps              | 4170     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19906    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0477   |
# |    n_updates        | 4951     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1656     |
# |    fps              | 4170     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19947    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00737  |
# |    n_updates        | 4961     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1660     |
# |    fps              | 4170     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19982    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0217   |
# |    n_updates        | 4970     |
# ----------------------------------
# Eval num_timesteps=20000, episode_reward=9.80 +/- 0.75
# Episode length: 9.80 +/- 0.75
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 9.8      |
# |    mean_reward      | 9.8      |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 20000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0798   |
# |    n_updates        | 4974     |
# ----------------------------------
